# %%
from os import system
import os
import pandas as pd
import numpy as np
import time
import copy
import pickle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import lr_scheduler
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv('data.csv')
data[0:10]
# Out:
#      diff_x    diff_y    diff_z  diff_phi  diff_theta  diff_psi     r_std  \
# 0  0.018112 -3.781020 -0.315103 -0.035606   -0.033205  0.621026  0.008387
# 1  0.139085 -1.232157  0.292487 -0.035606   -0.033205 -0.495721  0.007725
# 2  0.023585 -3.765141 -0.329528 -0.035606   -0.033205  0.635356  0.008343
# 3  0.108880 -1.175414  0.348324 -0.035606   -0.033205 -0.484876  0.008004
# 4  0.022564 -3.771321 -0.320583 -0.035606   -0.033205  0.621327  0.008359
# 5  0.094577 -1.189581  0.343223 -0.035606   -0.033205 -0.547167  0.007935
# 6  0.016289 -3.766810 -0.331063 -0.035606   -0.033205  0.635615  0.008329
# 7  0.118642 -1.178074  0.353251 -0.035606   -0.033205 -0.483459  0.007992
# 8  0.013476 -3.770341 -0.316664 -0.035606   -0.033205  0.636008  0.008350
# 9  0.130208 -1.227581  0.298760 -0.035606   -0.033205 -0.434223  0.007747
#
#     phi_std  theta_std   psi_std  time_or_speed        Tf  v_average  \
# 0  0.000097   0.000175  0.001913              1  6.535084   0.580585
# 1  0.000183   0.000219  0.001930              1  2.194358   0.580585
# 2  0.000097   0.000175  0.001912              0  3.663285   0.580585
# 3  0.000190   0.000221  0.001936              0  1.192886   0.580585
# 4  0.000097   0.000175  0.001913              1  1.615679   2.342661
# 5  0.000189   0.000221  0.001936              1  0.530044   2.342661
# 6  0.000096   0.000175  0.001912              0  3.764532   2.342661
# 7  0.000189   0.000221  0.001935              0  1.230105   2.342661
# 8  0.000096   0.000175  0.001912              1  3.221203   1.174604
# 9  0.000183   0.000219  0.001929              1  1.081305   1.174604
#
#            Cost
# 0  26332.768538
# 1   2213.359376
# 2   8295.372169
# 3    697.090464
# 4   1704.972584
# 5    118.393602
# 6   8756.956686
# 7    738.558134
# 8   6427.191253
# 9    545.897450

# %%
eps = 0.06
